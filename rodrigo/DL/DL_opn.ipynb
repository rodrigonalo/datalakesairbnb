# %%
from azure.storage.blob import BlobServiceClient
import pandas as pd
import io
from concurrent.futures import ThreadPoolExecutor, as_completed
from openai import OpenAI

# %%
# Define your Azure Blob Storage connection string and container name
connection_string = "DefaultEndpointsProtocol=https;AccountName=datalakestoragerentscape;AccountKey=w6Edf3np1A18vQIei31unvKWjGpyDUBqexvVauAwCeqOmnF1Bq7WsIEVplSEW+hT0q4ZzDi2KNh4+AStrOcI6g==;EndpointSuffix=core.windows.net"
container_name = "rentscape-blob"

# Initialize BlobServiceClient and ContainerClient
blob_service_client = BlobServiceClient.from_connection_string(connection_string)
container_client = blob_service_client.get_container_client(container_name)

# Function to download blob and load it into a DataFrame
def download_and_load_blob(blob_name):
    try:
        blob_client = container_client.get_blob_client(blob_name)
        blob_data = blob_client.download_blob().readall()
        df = pd.read_csv(io.StringIO(blob_data.decode('utf-8')))
        
        # Generate a variable name from the blob name, making it a valid Python variable
        variable_name = blob_name.replace('/', '_').replace('.csv', '')
        
        # Set the DataFrame to a global variable with this name
        globals()[variable_name] = df
        print(f"Loaded {blob_name} into DataFrame: {variable_name}")
    except Exception as e:
        print(f"Failed to process {blob_name}: {e}")

# List of blobs to process (only CSV files containing "listings" in the title)
blob_names = [
    blob.name for blob in container_client.list_blobs() 
    if blob.name.endswith('.csv') and 'listings' in blob.name
]

# Use ThreadPoolExecutor for parallel processing
with ThreadPoolExecutor(max_workers=10) as executor:
    # Submit tasks for each blob
    futures = {executor.submit(download_and_load_blob, blob_name): blob_name for blob_name in blob_names}
    
    # Process results as they complete
    for future in as_completed(futures):
        future.result()  # Ensures all processing completes


# Now, each CSV file is loaded into a DataFrame with a variable name based on its file name
# Out:
# Loaded prague_listings.csv into DataFrame: prague_listings
# Loaded barcelona_listings.csv into DataFrame: barcelona_listings

# %%
# Process Prague Listings
unique_neighbourhoods_prague = prague_listings['host_neighbourhood'].unique()
unique_neighbourhoods_prague_df = pd.DataFrame(unique_neighbourhoods_prague, columns=['Unique_Neighbourhoods'])
unique_neighbourhoods_prague_df = unique_neighbourhoods_prague_df.sort_values(by='Unique_Neighbourhoods', ascending=True)
unique_neighbourhoods_prague_df.reset_index(drop=True, inplace=True)

# Process Barcelona Listings
unique_neighbourhoods_barcelona = barcelona_listings['host_neighbourhood'].unique()
unique_neighbourhoods_barcelona_df = pd.DataFrame(unique_neighbourhoods_barcelona, columns=['Unique_Neighbourhoods'])
unique_neighbourhoods_barcelona_df = unique_neighbourhoods_barcelona_df.sort_values(by='Unique_Neighbourhoods', ascending=True)
unique_neighbourhoods_barcelona_df.reset_index(drop=True, inplace=True)

# %%
unique_neighbourhoods_barcelona_df
# Out:
#               Unique_Neighbourhoods
# 0                         Achrafieh
# 1                          Albaicín
# 2                          Almenara
# 3                 Amsterdam Centrum
# 4    Angle RP Albert 1er. belvédère
# ..                              ...
# 142                          Zona 9
# 143                   el Fort Pienc
# 144              la Sagrada Familia
# 145              la Sagrada Família
# 146                             NaN
#
# [147 rows x 1 columns]

# %%
from openai import OpenAI
import pandas as pd

# Initialize OpenAI client
client = OpenAI(api_key='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')

# Initialize a counter variable
execution_count = 0

# General function to assess neighborhoods with regulations
def assess_neighbourhood_with_regulations(neighbourhood, total_rows):
    global execution_count  # Use the global counter
    execution_count += 1  # Increment the counter for each processed row

    # Calculate remaining rows
    remaining_rows = total_rows - execution_count

    # Check if the neighbourhood name is missing or empty
    if not isinstance(neighbourhood, str) or not neighbourhood.strip():
        print(f"Execution Count: {execution_count}")
        print(f"Remaining Rows: {remaining_rows}")
        print(f"Neighbourhood: {neighbourhood}\nExposure Score: N/A\nRising Star: N/A\nRegulations: N/A\n")
        return "N/A", "N/A", "N/A"

    # Construct the enhanced prompt
    prompt = (
        f"Analyze the neighborhood '{neighbourhood}' in the context of Airbnb listings and news. "
        f"1) From 1 to 5, rate how much this neighborhood has appeared in news articles over the last few years regarding Airbnb being a problem. "
        f"2) Is this area a 'Rising Star' in terms of popularity? Respond with 'Yes' or 'No'. "
        f"3) Are there any local regulations on short-term rentals? Respond with 'Yes' or 'No'. "
        f"Provide the answers in the format: Exposure Score: <number>, Rising Star: <Yes/No>, Regulations: <Yes/No>. Do not include any additional text."
    )

    try:
        # Make the API call to OpenAI
        completion = client.chat.completions.create(
            model="gpt-4o-mini",  # Replace with your preferred model
            messages=[
                {"role": "system", "content": "You are an expert in analyzing urban issues related to tourism and housing."},
                {"role": "user", "content": prompt}
            ]
        )

        # Extract the response and split it into the three outputs
        response = completion.choices[0].message.content.strip()
        exposure_score, rising_star, regulations = response.replace(" ", "").split(",")
        exposure_score = exposure_score.split(":")[1]
        rising_star = rising_star.split(":")[1]
        regulations = regulations.split(":")[1]

        # Print the neighbourhood, scores, execution count, and remaining rows
        print(f"Execution Count: {execution_count}")
        print(f"Remaining Rows: {remaining_rows}")
        print(f"Neighbourhood: {neighbourhood}\nExposure Score: {exposure_score}\nRising Star: {rising_star}\nRegulations: {regulations}\n")

        return exposure_score, rising_star, regulations

    except Exception as e:
        print(f"An error occurred: {e}")
        return "Error", "Error", "Error"


# Function to process a DataFrame
def process_neighbourhoods(df):
    global execution_count
    execution_count = 0  # Reset the counter for each DataFrame
    total_rows = len(df)  # Calculate total rows for the current DataFrame

    # Apply the assessment function to each neighbourhood
    df[['Exposure_Score', 'Rising_Star', 'Regulations']] = df['Unique_Neighbourhoods'].apply(
        lambda neighbourhood: pd.Series(assess_neighbourhood_with_regulations(neighbourhood, total_rows))
    )
    return df


# Process Prague Neighbourhoods
print("Processing Prague Neighbourhoods...")
unique_neighbourhoods_prague_df = process_neighbourhoods(unique_neighbourhoods_prague_df)
print(unique_neighbourhoods_prague_df)

# Process Barcelona Neighbourhoods
print("\nProcessing Barcelona Neighbourhoods...")
unique_neighbourhoods_barcelona_df = process_neighbourhoods(unique_neighbourhoods_barcelona_df)
print(unique_neighbourhoods_barcelona_df)
# Out:
# Processing Prague Neighbourhoods...
# Execution Count: 1
# Remaining Rows: 128
# Neighbourhood: Anděl
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 2
# Remaining Rows: 127
# Neighbourhood: Barrandov
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 3
# Remaining Rows: 126
# Neighbourhood: Belárie
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 4
# Remaining Rows: 125
# Neighbourhood: Bližná
# Exposure Score: 3
# Rising Star: Yes
# Regulations: No.
#
# Execution Count: 5
# Remaining Rows: 124
# Neighbourhood: Bohnice
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 6
# Remaining Rows: 123
# Neighbourhood: Braník
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 7
# Remaining Rows: 122
# Neighbourhood: Bubeneč
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 8
# Remaining Rows: 121
# Neighbourhood: Budějovické Předměstí
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 9
# Remaining Rows: 120
# Neighbourhood: Břevnov
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 10
# Remaining Rows: 119
# Neighbourhood: Chodov
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 11
# Remaining Rows: 118
# Neighbourhood: Dejvice
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 12
# Remaining Rows: 117
# Neighbourhood: Dolní Měcholupy
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 13
# Remaining Rows: 116
# Neighbourhood: Dolní Počernice
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 14
# Remaining Rows: 115
# Neighbourhood: Flean More
# Exposure Score: 3
# Rising Star: Yes
# Regulations: No
#
# Execution Count: 15
# Remaining Rows: 114
# Neighbourhood: Florenc
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 16
# Remaining Rows: 113
# Neighbourhood: Hanspaulka
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 17
# Remaining Rows: 112
# Neighbourhood: Hloubětín
# Exposure Score: 2
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 18
# Remaining Rows: 111
# Neighbourhood: Hlubočepy
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 19
# Remaining Rows: 110
# Neighbourhood: Hodkovice
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 20
# Remaining Rows: 109
# Neighbourhood: Hodkovičky
# Exposure Score: 2
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 21
# Remaining Rows: 108
# Neighbourhood: Holešovice
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 22
# Remaining Rows: 107
# Neighbourhood: Horní Rokytnice
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 23
# Remaining Rows: 106
# Neighbourhood: Hostavice
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 24
# Remaining Rows: 105
# Neighbourhood: Hostivař
# Exposure Score: 3
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 25
# Remaining Rows: 104
# Neighbourhood: Hořejší Vrchlabí
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 26
# Remaining Rows: 103
# Neighbourhood: Hradčany
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 27
# Remaining Rows: 102
# Neighbourhood: Hraničná
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 28
# Remaining Rows: 101
# Neighbourhood: Invalidovna
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 29
# Remaining Rows: 100
# Neighbourhood: Jinonice
# Exposure Score: 2
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 30
# Remaining Rows: 99
# Neighbourhood: Josefov
# Exposure Score: 4
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 31
# Remaining Rows: 98
# Neighbourhood: Kamýk
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 32
# Remaining Rows: 97
# Neighbourhood: Karlín
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 33
# Remaining Rows: 96
# Neighbourhood: Kbely
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 34
# Remaining Rows: 95
# Neighbourhood: Klánovice
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 35
# Remaining Rows: 94
# Neighbourhood: Kobylisy
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 36
# Remaining Rows: 93
# Neighbourhood: Komořany
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 37
# Remaining Rows: 92
# Neighbourhood: Košíře
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 38
# Remaining Rows: 91
# Neighbourhood: Krč
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 39
# Remaining Rows: 90
# Neighbourhood: Kunratice
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 40
# Remaining Rows: 89
# Neighbourhood: Kyje
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 41
# Remaining Rows: 88
# Neighbourhood: Lahovice
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 42
# Remaining Rows: 87
# Neighbourhood: Letná
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 43
# Remaining Rows: 86
# Neighbourhood: Letňany
# Exposure Score: 2
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 44
# Remaining Rows: 85
# Neighbourhood: Libeň
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 45
# Remaining Rows: 84
# Neighbourhood: Liboc
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 46
# Remaining Rows: 83
# Neighbourhood: Libuš
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 47
# Remaining Rows: 82
# Neighbourhood: Lincoln Heights
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 48
# Remaining Rows: 81
# Neighbourhood: Mala Strana
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 49
# Remaining Rows: 80
# Neighbourhood: Malá Strana
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 50
# Remaining Rows: 79
# Neighbourhood: Michle
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 51
# Remaining Rows: 78
# Neighbourhood: Midtown Atlanta
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 52
# Remaining Rows: 77
# Neighbourhood: Mladá Boleslav I
# Exposure Score: 3
# Rising Star: Yes
# Regulations: No
#
# Execution Count: 53
# Remaining Rows: 76
# Neighbourhood: Modřany
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 54
# Remaining Rows: 75
# Neighbourhood: Motol
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 55
# Remaining Rows: 74
# Neighbourhood: Město
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 56
# Remaining Rows: 73
# Neighbourhood: Můstek
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 57
# Remaining Rows: 72
# Neighbourhood: Nebušice
# Exposure Score: 3
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 58
# Remaining Rows: 71
# Neighbourhood: Northeast Orlando
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 59
# Remaining Rows: 70
# Neighbourhood: Nové Město
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 60
# Remaining Rows: 69
# Neighbourhood: Nusle
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 61
# Remaining Rows: 68
# Neighbourhood: Palmovka
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 62
# Remaining Rows: 67
# Neighbourhood: Parque Chacabuco
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 63
# Remaining Rows: 66
# Neighbourhood: Petrovice
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 64
# Remaining Rows: 65
# Neighbourhood: Petrská čtvrť
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 65
# Remaining Rows: 64
# Neighbourhood: Place d'Italie - Quartier Chinois
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 66
# Remaining Rows: 63
# Neighbourhood: Podolí
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 67
# Remaining Rows: 62
# Neighbourhood: Prague 10
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 68
# Remaining Rows: 61
# Neighbourhood: Prague 11
# Exposure Score: 2
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 69
# Remaining Rows: 60
# Neighbourhood: Prague 12
# Exposure Score: 3
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 70
# Remaining Rows: 59
# Neighbourhood: Prague 13
# Exposure Score: 2
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 71
# Remaining Rows: 58
# Neighbourhood: Prague 14
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 72
# Remaining Rows: 57
# Neighbourhood: Prague 15
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 73
# Remaining Rows: 56
# Neighbourhood: Prague 16
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 74
# Remaining Rows: 55
# Neighbourhood: Prague 17
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 75
# Remaining Rows: 54
# Neighbourhood: Prague 18
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 76
# Remaining Rows: 53
# Neighbourhood: Prague 2
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 77
# Remaining Rows: 52
# Neighbourhood: Prague 20
# Exposure Score: 2
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 78
# Remaining Rows: 51
# Neighbourhood: Prague 21
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 79
# Remaining Rows: 50
# Neighbourhood: Prague 3
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 80
# Remaining Rows: 49
# Neighbourhood: Prague 4
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 81
# Remaining Rows: 48
# Neighbourhood: Prague 5
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 82
# Remaining Rows: 47
# Neighbourhood: Prague 6
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 83
# Remaining Rows: 46
# Neighbourhood: Prague 8
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 84
# Remaining Rows: 45
# Neighbourhood: Prague 9
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 85
# Remaining Rows: 44
# Neighbourhood: Prosek
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 86
# Remaining Rows: 43
# Neighbourhood: Putney Heath
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 87
# Remaining Rows: 42
# Neighbourhood: Písnice
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 88
# Remaining Rows: 41
# Neighbourhood: Quaid Block
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 89
# Remaining Rows: 40
# Neighbourhood: Radotín
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 90
# Remaining Rows: 39
# Neighbourhood: Rohanský ostrov
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 91
# Remaining Rows: 38
# Neighbourhood: Ruzyně
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 92
# Remaining Rows: 37
# Neighbourhood: Sant Pere/Santa Caterina
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 93
# Remaining Rows: 36
# Neighbourhood: Satalice
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 94
# Remaining Rows: 35
# Neighbourhood: Sedlec
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 95
# Remaining Rows: 34
# Neighbourhood: Smíchov
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 96
# Remaining Rows: 33
# Neighbourhood: Staré Město
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 97
# Remaining Rows: 32
# Neighbourhood: Staré Sedlo
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 98
# Remaining Rows: 31
# Neighbourhood: Stodůlky
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 99
# Remaining Rows: 30
# Neighbourhood: Strašnice
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 100
# Remaining Rows: 29
# Neighbourhood: Střešovice
# Exposure Score: 3
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 101
# Remaining Rows: 28
# Neighbourhood: Střížkov
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 102
# Remaining Rows: 27
# Neighbourhood: Suomi Hloubětín
# Exposure Score: 2
# Rising Star: Yes
# Regulations: No.
#
# Execution Count: 103
# Remaining Rows: 26
# Neighbourhood: Terézváros - District VI.
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 104
# Remaining Rows: 25
# Neighbourhood: Točná
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 105
# Remaining Rows: 24
# Neighbourhood: Troja
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 106
# Remaining Rows: 23
# Neighbourhood: Třebonice
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 107
# Remaining Rows: 22
# Neighbourhood: Uhříněves
# Exposure Score: 2
# Rising Star: Yes
# Regulations: No.
#
# Execution Count: 108
# Remaining Rows: 21
# Neighbourhood: Veleslavín
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 109
# Remaining Rows: 20
# Neighbourhood: Velká Chuchle
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 110
# Remaining Rows: 19
# Neighbourhood: Vinohrady
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 111
# Remaining Rows: 18
# Neighbourhood: Vokovice
# Exposure Score: 3
# Rising Star: Yes
# Regulations: No.
#
# Execution Count: 112
# Remaining Rows: 17
# Neighbourhood: Vršovice
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 113
# Remaining Rows: 16
# Neighbourhood: Vysoká Lípa
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 114
# Remaining Rows: 15
# Neighbourhood: Vysočany
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 115
# Remaining Rows: 14
# Neighbourhood: Vyšehrad
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 116
# Remaining Rows: 13
# Neighbourhood: Zbraslav
# Exposure Score: 3
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 117
# Remaining Rows: 12
# Neighbourhood: Zličín
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 118
# Remaining Rows: 11
# Neighbourhood: Záběhlice
# Exposure Score: 2
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 119
# Remaining Rows: 10
# Neighbourhood: Újezd u Průhonic
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 120
# Remaining Rows: 9
# Neighbourhood: Častonice
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 121
# Remaining Rows: 8
# Neighbourhood: Černý Most
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 122
# Remaining Rows: 7
# Neighbourhood: Čimice
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 123
# Remaining Rows: 6
# Neighbourhood: Čistá v Krkonoších
# Exposure Score: 2
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 124
# Remaining Rows: 5
# Neighbourhood: Řeporyje
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 125
# Remaining Rows: 4
# Neighbourhood: Řepy
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 126
# Remaining Rows: 3
# Neighbourhood: Şişli
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 127
# Remaining Rows: 2
# Neighbourhood: Štěrboholy
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 128
# Remaining Rows: 1
# Neighbourhood: Žižkov
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 129
# Remaining Rows: 0
# Neighbourhood: nan
# Exposure Score: N/A
# Rising Star: N/A
# Regulations: N/A
#
#     Unique_Neighbourhoods Exposure_Score Rising_Star Regulations
# 0                   Anděl              4         Yes         Yes
# 1               Barrandov              3         Yes         Yes
# 2                 Belárie              3         Yes        Yes.
# 3                  Bližná              3         Yes         No.
# 4                 Bohnice              2          No        Yes.
# ..                    ...            ...         ...         ...
# 124                  Řepy              2          No        Yes.
# 125                 Şişli              4         Yes        Yes.
# 126            Štěrboholy              2          No         Yes
# 127                Žižkov              4         Yes         Yes
# 128                   NaN            N/A         N/A         N/A
#
# [129 rows x 4 columns]
#
# Processing Barcelona Neighbourhoods...
# Execution Count: 1
# Remaining Rows: 146
# Neighbourhood: Achrafieh
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 2
# Remaining Rows: 145
# Neighbourhood: Albaicín
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 3
# Remaining Rows: 144
# Neighbourhood: Almenara
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 4
# Remaining Rows: 143
# Neighbourhood: Amsterdam Centrum
# Exposure Score: 4
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 5
# Remaining Rows: 142
# Neighbourhood: Angle RP Albert 1er. belvédère
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 6
# Remaining Rows: 141
# Neighbourhood: Barrio Norte
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 7
# Remaining Rows: 140
# Neighbourhood: Belgrano Residencial
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 8
# Remaining Rows: 139
# Neighbourhood: Betaghstown
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 9
# Remaining Rows: 138
# Neighbourhood: Boa Viagem
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 10
# Remaining Rows: 137
# Neighbourhood: Bondi
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 11
# Remaining Rows: 136
# Neighbourhood: Buttes-Chaumont - Belleville
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 12
# Remaining Rows: 135
# Neighbourhood: Camp d'en Grassot i Gràcia Nova
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 13
# Remaining Rows: 134
# Neighbourhood: Campo Marzo
# Exposure Score: 3
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 14
# Remaining Rows: 133
# Neighbourhood: Can Baro
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 15
# Remaining Rows: 132
# Neighbourhood: Carmel
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 16
# Remaining Rows: 131
# Neighbourhood: Carmel Woods
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 17
# Remaining Rows: 130
# Neighbourhood: Central Vancouver
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 18
# Remaining Rows: 129
# Neighbourhood: Champs-Elysées
# Exposure Score: 4
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 19
# Remaining Rows: 128
# Neighbourhood: Chicó Norte
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 20
# Remaining Rows: 127
# Neighbourhood: Cihangir
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 21
# Remaining Rows: 126
# Neighbourhood: Ciutat Vella
# Exposure Score: 5
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 22
# Remaining Rows: 125
# Neighbourhood: Colegiales
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 23
# Remaining Rows: 124
# Neighbourhood: Comercio
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 24
# Remaining Rows: 123
# Neighbourhood: Commerce - Dupleix
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 25
# Remaining Rows: 122
# Neighbourhood: Copacabana
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 26
# Remaining Rows: 121
# Neighbourhood: Cortes
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 27
# Remaining Rows: 120
# Neighbourhood: Crown Heights
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 28
# Remaining Rows: 119
# Neighbourhood: De Beauvoir Town
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 29
# Remaining Rows: 118
# Neighbourhood: Diagonal Mar
# Exposure Score: 2
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 30
# Remaining Rows: 117
# Neighbourhood: Diagonal Mar - La Mar Bella
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 31
# Remaining Rows: 116
# Neighbourhood: Dorp Soto
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 32
# Remaining Rows: 115
# Neighbourhood: Dreta de l'Eixample
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 33
# Remaining Rows: 114
# Neighbourhood: Earls Court
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 34
# Remaining Rows: 113
# Neighbourhood: Edgewater
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 35
# Remaining Rows: 112
# Neighbourhood: Eixample
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 36
# Remaining Rows: 111
# Neighbourhood: El Baix Guinardó
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 37
# Remaining Rows: 110
# Neighbourhood: El Besòs i el Maresme
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 38
# Remaining Rows: 109
# Neighbourhood: El Bon Pastor
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 39
# Remaining Rows: 108
# Neighbourhood: El Born
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 40
# Remaining Rows: 107
# Neighbourhood: El Camp de l'Arpa del Clot
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 41
# Remaining Rows: 106
# Neighbourhood: El Clot
# Exposure Score: 3
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 42
# Remaining Rows: 105
# Neighbourhood: El Coll
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 43
# Remaining Rows: 104
# Neighbourhood: El Congrés i els Indians
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 44
# Remaining Rows: 103
# Neighbourhood: El Gòtic
# Exposure Score: 4
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 45
# Remaining Rows: 102
# Neighbourhood: El Poble-sec
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 46
# Remaining Rows: 101
# Neighbourhood: El Poblenou
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 47
# Remaining Rows: 100
# Neighbourhood: El Putget i Farró
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 48
# Remaining Rows: 99
# Neighbourhood: El Raval
# Exposure Score: 5
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 49
# Remaining Rows: 98
# Neighbourhood: Estrella
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 50
# Remaining Rows: 97
# Neighbourhood: Friedrichshain
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 51
# Remaining Rows: 96
# Neighbourhood: Gare du Nord - Gare de I'Est
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 52
# Remaining Rows: 95
# Neighbourhood: Glòries - El Parc
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 53
# Remaining Rows: 94
# Neighbourhood: Goose Hollow
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 54
# Remaining Rows: 93
# Neighbourhood: Gràcia
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 55
# Remaining Rows: 92
# Neighbourhood: Guinardó
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 56
# Remaining Rows: 91
# Neighbourhood: Hammersmith
# Exposure Score: 3
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 57
# Remaining Rows: 90
# Neighbourhood: Horta
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 58
# Remaining Rows: 89
# Neighbourhood: Hoxton
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 59
# Remaining Rows: 88
# Neighbourhood: III Arrondissement
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 60
# Remaining Rows: 87
# Neighbourhood: Ibiza
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 61
# Remaining Rows: 86
# Neighbourhood: Jordaan
# Exposure Score: 4
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 62
# Remaining Rows: 85
# Neighbourhood: Józsefváros - District VIII.
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 63
# Remaining Rows: 84
# Neighbourhood: Kauaʻi
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 64
# Remaining Rows: 83
# Neighbourhood: Kolonaki
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 65
# Remaining Rows: 82
# Neighbourhood: L'Antiga Esquerra de l'Eixample
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 66
# Remaining Rows: 81
# Neighbourhood: LB of Brent
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 67
# Remaining Rows: 80
# Neighbourhood: LB of Hackney
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 68
# Remaining Rows: 79
# Neighbourhood: La Barceloneta
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 69
# Remaining Rows: 78
# Neighbourhood: La Blanca, San Marcos
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 70
# Remaining Rows: 77
# Neighbourhood: La Daille
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 71
# Remaining Rows: 76
# Neighbourhood: La Font d'en Fargues
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 72
# Remaining Rows: 75
# Neighbourhood: La Guineueta - Canyelles
# Exposure Score: 3
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 73
# Remaining Rows: 74
# Neighbourhood: La Maternitat i Sant Ramon
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 74
# Remaining Rows: 73
# Neighbourhood: La Nova Esquerra de l'Eixample
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 75
# Remaining Rows: 72
# Neighbourhood: La Prosperitat
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 76
# Remaining Rows: 71
# Neighbourhood: La Sagrada Família
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 77
# Remaining Rows: 70
# Neighbourhood: La Sagrera
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 78
# Remaining Rows: 69
# Neighbourhood: La Salut
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 79
# Remaining Rows: 68
# Neighbourhood: La Teixonera
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 80
# Remaining Rows: 67
# Neighbourhood: La Trinitat Vella
# Exposure Score: 3
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 81
# Remaining Rows: 66
# Neighbourhood: La Vall d'Hebron
# Exposure Score: 3
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 82
# Remaining Rows: 65
# Neighbourhood: La Verneda i La Pau
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 83
# Remaining Rows: 64
# Neighbourhood: La Vila Olímpica
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 84
# Remaining Rows: 63
# Neighbourhood: Le Marais
# Exposure Score: 4
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 85
# Remaining Rows: 62
# Neighbourhood: Les Corts
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 86
# Remaining Rows: 61
# Neighbourhood: Les Corts (Nabe)
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 87
# Remaining Rows: 60
# Neighbourhood: Les Tres Torres
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 88
# Remaining Rows: 59
# Neighbourhood: Llefià
# Exposure Score: 3
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 89
# Remaining Rows: 58
# Neighbourhood: Los Romanes
# Exposure Score: 2
# Rising Star: Yes
# Regulations: No.
#
# Execution Count: 90
# Remaining Rows: 57
# Neighbourhood: Mijas Costa
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 91
# Remaining Rows: 56
# Neighbourhood: Mile End
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 92
# Remaining Rows: 55
# Neighbourhood: Mitte
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 93
# Remaining Rows: 54
# Neighbourhood: Montbau
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 94
# Remaining Rows: 53
# Neighbourhood: Navas
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 95
# Remaining Rows: 52
# Neighbourhood: Nine Elms
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 96
# Remaining Rows: 51
# Neighbourhood: Nové Město
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 97
# Remaining Rows: 50
# Neighbourhood: Nueva Córdoba
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 98
# Remaining Rows: 49
# Neighbourhood: Palermo
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 99
# Remaining Rows: 48
# Neighbourhood: Palermo Hollywood
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 100
# Remaining Rows: 47
# Neighbourhood: Pasing - Obermenzing
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 101
# Remaining Rows: 46
# Neighbourhood: Pedralbes
# Exposure Score: 3
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 102
# Remaining Rows: 45
# Neighbourhood: Playa del Inglés
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 103
# Remaining Rows: 44
# Neighbourhood: Polanco
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 104
# Remaining Rows: 43
# Neighbourhood: Porta
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 105
# Remaining Rows: 42
# Neighbourhood: Prati
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 106
# Remaining Rows: 41
# Neighbourhood: Provençals del Poblenou
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 107
# Remaining Rows: 40
# Neighbourhood: Quesada
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 108
# Remaining Rows: 39
# Neighbourhood: RB of Kingston upon Thames
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 109
# Remaining Rows: 38
# Neighbourhood: Recoletos
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 110
# Remaining Rows: 37
# Neighbourhood: Sant Andreu de Palomar
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 111
# Remaining Rows: 36
# Neighbourhood: Sant Antoni
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 112
# Remaining Rows: 35
# Neighbourhood: Sant Genís dels Agudells
# Exposure Score: 3
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 113
# Remaining Rows: 34
# Neighbourhood: Sant Gervasi - Galvany
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 114
# Remaining Rows: 33
# Neighbourhood: Sant Gervasi - la Bonanova
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 115
# Remaining Rows: 32
# Neighbourhood: Sant Martí de Provençals
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 116
# Remaining Rows: 31
# Neighbourhood: Sant Pere/Santa Caterina
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 117
# Remaining Rows: 30
# Neighbourhood: Santa Catarina
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 118
# Remaining Rows: 29
# Neighbourhood: Sants-Montjuïc
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 119
# Remaining Rows: 28
# Neighbourhood: Sarrià
# Exposure Score: 3
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 120
# Remaining Rows: 27
# Neighbourhood: Sarrià-Sant Gervasi
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 121
# Remaining Rows: 26
# Neighbourhood: South Columbus
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 122
# Remaining Rows: 25
# Neighbourhood: St Martí
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 123
# Remaining Rows: 24
# Neighbourhood: Sunset Beach
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 124
# Remaining Rows: 23
# Neighbourhood: São Cristóvão e São Lourenço
# Exposure Score: 3
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 125
# Remaining Rows: 22
# Neighbourhood: Terézváros - District VI.
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 126
# Remaining Rows: 21
# Neighbourhood: Torre Baró
# Exposure Score: 3
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 127
# Remaining Rows: 20
# Neighbourhood: Trastevere
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 128
# Remaining Rows: 19
# Neighbourhood: Trieste
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 129
# Remaining Rows: 18
# Neighbourhood: Turó de la Peira - Can Peguera
# Exposure Score: 3
# Rising Star: No
# Regulations: Yes.
#
# Execution Count: 130
# Remaining Rows: 17
# Neighbourhood: Urbanització Bassetes
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 131
# Remaining Rows: 16
# Neighbourhood: Urbanización Alfa Mar
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 132
# Remaining Rows: 15
# Neighbourhood: Urbanización Doña Lola
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 133
# Remaining Rows: 14
# Neighbourhood: Urbanización Princesa Kristina
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 134
# Remaining Rows: 13
# Neighbourhood: Urbanización la Almedia
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 135
# Remaining Rows: 12
# Neighbourhood: Vallcarca i els Penitents
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 136
# Remaining Rows: 11
# Neighbourhood: Verdum - Los Roquetes
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 137
# Remaining Rows: 10
# Neighbourhood: Vila de Gràcia
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 138
# Remaining Rows: 9
# Neighbourhood: Vilapicina i la Torre Llobeta
# Exposure Score: 2
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 139
# Remaining Rows: 8
# Neighbourhood: Villa Crespo
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 140
# Remaining Rows: 7
# Neighbourhood: Vršovice
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 141
# Remaining Rows: 6
# Neighbourhood: Wimbledon
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 142
# Remaining Rows: 5
# Neighbourhood: Zona 5
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes.
#
# Execution Count: 143
# Remaining Rows: 4
# Neighbourhood: Zona 9
# Exposure Score: 3
# Rising Star: No
# Regulations: Yes
#
# Execution Count: 144
# Remaining Rows: 3
# Neighbourhood: el Fort Pienc
# Exposure Score: 3
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 145
# Remaining Rows: 2
# Neighbourhood: la Sagrada Familia
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 146
# Remaining Rows: 1
# Neighbourhood: la Sagrada Família
# Exposure Score: 4
# Rising Star: Yes
# Regulations: Yes
#
# Execution Count: 147
# Remaining Rows: 0
# Neighbourhood: nan
# Exposure Score: N/A
# Rising Star: N/A
# Regulations: N/A
#
#               Unique_Neighbourhoods Exposure_Score Rising_Star Regulations
# 0                         Achrafieh              4         Yes        Yes.
# 1                          Albaicín              4         Yes        Yes.
# 2                          Almenara              3         Yes        Yes.
# 3                 Amsterdam Centrum              4          No         Yes
# 4    Angle RP Albert 1er. belvédère              3         Yes         Yes
# ..                              ...            ...         ...         ...
# 142                          Zona 9              3          No         Yes
# 143                   el Fort Pienc              3         Yes         Yes
# 144              la Sagrada Familia              4         Yes         Yes
# 145              la Sagrada Família              4         Yes         Yes
# 146                             NaN            N/A         N/A         N/A
#
# [147 rows x 4 columns]

# %%
unique_neighbourhoods_barcelona_df
# Out:
#               Unique_Neighbourhoods Exposure_Score Rising_Star Regulations
# 0                         Achrafieh              4         Yes        Yes.
# 1                          Albaicín              4         Yes        Yes.
# 2                          Almenara              3         Yes        Yes.
# 3                 Amsterdam Centrum              4          No         Yes
# 4    Angle RP Albert 1er. belvédère              3         Yes         Yes
# ..                              ...            ...         ...         ...
# 142                          Zona 9              3          No         Yes
# 143                   el Fort Pienc              3         Yes         Yes
# 144              la Sagrada Familia              4         Yes         Yes
# 145              la Sagrada Família              4         Yes         Yes
# 146                             NaN            N/A         N/A         N/A
#
# [147 rows x 4 columns]

# %%
from azure.storage.blob import BlobServiceClient
import pandas as pd

# SAS token and container URL
sas_token = "sp=racwdl&st=2024-12-01T01:41:21Z&se=2025-01-28T09:41:21Z&spr=https&sv=2022-11-02&sr=c&sig=OpjDBOtKtITxiEAnzF7wkFAvAyLCmijQLyz93sxQi78%3D"
container_url = "https://datalakestoragerentscape.blob.core.windows.net/openai-rentscape-blob"

# Function to upload a DataFrame to Blob Storage
def upload_dataframe_to_blob(df, blob_name):
    # Save DataFrame to a local CSV file
    file_path = f"{blob_name}.csv"
    df.to_csv(file_path, index=False)

    # Connect to the Blob Container
    blob_service_client = BlobServiceClient(account_url=container_url, credential=sas_token)
    container_client = blob_service_client.get_container_client(container="openai-rentscape-blob")

    # Upload the CSV file to the Blob Storage
    with open(file_path, "rb") as data:
        container_client.upload_blob(name=blob_name, data=data, overwrite=True)
    
    print(f"Uploaded {blob_name} to {container_url}")

# Update file names for the Blob Storage
upload_dataframe_to_blob(unique_neighbourhoods_barcelona_df, "barcelona_neighborhoods_details.csv")
upload_dataframe_to_blob(unique_neighbourhoods_prague_df, "prague_neighborhoods_details.csv")
# Out:
# Uploaded barcelona_neighborhoods_details.csv to https://datalakestoragerentscape.blob.core.windows.net/openai-rentscape-blob
# Uploaded prague_neighborhoods_details.csv to https://datalakestoragerentscape.blob.core.windows.net/openai-rentscape-blob
